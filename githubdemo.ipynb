# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswith-Dev/Machine-Learning/blob/main/githubdemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Ashwith Hello!')
# Out:
# Ashwith Hello!
